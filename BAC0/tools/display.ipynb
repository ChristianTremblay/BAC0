# %%
from BAC0.tools import const

FILE_HEADER = const.FILE_HEADER
FILE_FOOTER = const.FILE_FOOTER
TAG = const.TAG

template_example = {
    "names" : [("name", "dev_id")],
}

def convert(d, device_name=None, make_template=False):
    """
    Template : If true, will not populate name and device id so the file
    can be reused to create a dictionnary in T3 Studio with multiple
    devices. This will prevents us from switching dictionnary all the time.
    """
    list_of_tags = []
    device_id = None
    OBJECT_TYPE = {
        "analogValue": "AV",
        "analogInput": "AI",
        "analogOutput": "AO",
        "binaryInput": "BI",
        "binaryValue": "BV",
        "binaryOutput": "BO",
        "multiStateInput": "MI",
        "multiStateValue": "MV",
        "multiStateOutput": "MO",
    }
    DATATYPES = {
        "AI": "float",
        "AO": "float",
        "AV": "float",
        "BI": "boolean",
        "BO": "boolean",
        "BV": "boolean",
        "MI": "unsignedInt",
        "MO": "unsignedInt",
        "MV": "unsignedInt",
    }

    WRITE_PRIORITY = {
        "AI": 0,
        "AO": 8,
        "AV": 10,
        "BI": 0,
        "BO": 8,
        "BV": 10,
        "MI": 0,
        "MO": 8,
        "MV": 10,
    }

    if make_template:
        device_name = "$DEVICE_NAME"
        device_id = "$DEVICE_ID"

    data = {}
    for each in d.points:
        name = device_name if device_name else d.properties.name
        data["name"] = "{}/{}".format(name, each.properties.name)
        data["group"] = ""
        data["object_type"] = OBJECT_TYPE[each.properties.type]
        data["object_instance"] = each.properties.address
        data["device_id"] = device_id if device_id else d.properties.device_id
        data["data_type"] = DATATYPES[data["object_type"]]
        data["object_property"] = 85
        data["write_priority"] = WRITE_PRIORITY[data["object_type"]]
        data["cov"] = "false"
        data["refresh_time"] = 1000
        data["access_mode"] = "READ"
        data["active"] = "false"
        data["comment"] = each.properties.description
        data["array_index"] = -1
        list_of_tags.append(TAG.format(d=data))

    return (name, list_of_tags)

def build_from_templates(list_of_tags, config=None):
    """
    Config must be a list of tuple (name, device_id)
    """
    _lst_of_tags = []
    for each in config:
        name, device_id = each
        for each in list_of_tags:
            print(each)
            each = each.replace("$DEVICE_NAME", name)
            each = each.replace("DEVICE_ID", "{}".format(device_id))
            print(each)
            _lst_of_tags.append(each)
    return _lst_of_tags


def merge_templates(lst=[]):
    _lst = []
    for each in lst:
        _lst.extend(each)
    return _lst



def write_tags_import_file(name, list_of_tags):
    _content = FILE_HEADER
    for tag in list_of_tags:
        _content += tag
    _content += FILE_FOOTER
    with open("{}.xml".format(name), "w") as xml_file:
        xml_file.write(_content)

# %%
import BAC0
bacnet = BAC0.lite()
uc = BAC0.device('303:5', 5905, bacnet)
nep = BAC0.device('303:20', 153020, bacnet)
# Out:
# 2022-02-02 22:08:28,735 - INFO    | Starting BAC0 version 22.01.06dev (Lite)
# 2022-02-02 22:08:28,736 - INFO    | Use BAC0.log_level to adjust verbosity of the app.
# 2022-02-02 22:08:28,737 - INFO    | Ex. BAC0.log_level('silence') or BAC0.log_level('error')
# 2022-02-02 22:08:29,040 - INFO    | Using ip : 192.168.211.54
# ---------------------------------------------------------------------------
# InitializationError                       Traceback (most recent call last)
# <ipython-input-28-b486ba59265c> in <module>
#       1 import BAC0
# ----> 2 bacnet = BAC0.lite()
#       3 uc = BAC0.device('303:5', 5905, bacnet)
#       4 nep = BAC0.device('303:20', 153020, bacnet)
#
# ~\Anaconda3\lib\site-packages\BAC0\scripts\Lite.py in __init__(self, ip, port, mask, bbmdAddress, bbmdTTL, bdtable, ping, ping_delay, db_params, **params)
#     150             ip_addr = Address("{}/{}:{}".format(ip, mask, port))
#     151         self._log.info("Using ip : {ip_addr}".format(ip_addr=ip_addr))
# --> 152         Base.__init__(
#     153             self,
#     154             localIPAddr=ip_addr,
#
# ~\Anaconda3\lib\site-packages\BAC0\scripts\Base.py in __init__(self, localIPAddr, localObjName, deviceId, firmwareRevision, maxAPDULengthAccepted, maxSegmentsAccepted, segmentationSupported, bbmdAddress, bbmdTTL, bdtable, modelName, vendorId, vendorName, description)
#     132
#     133         if localIPAddr in Base._used_ips:
# --> 134             raise InitializationError(
#     135                 "IP Address provided ({}) already used by BAC0. Check if another software is using port 47808 on this network interface. If so, you can define multiple IP per interface. Or specify another IP using BAC0.lite(ip='IP/mask')".format(
#     136                     localIPAddr
#
# InitializationError: IP Address provided (192.168.211.54) already used by BAC0. Check if another software is using port 47808 on this network interface. If so, you can define multiple IP per interface. Or specify another IP using BAC0.lite(ip='IP/mask')

# %%
uc_template = convert(uc, make_template=True)
nep_template = convert(nep, make_template=True)

# %%
uc_template[1][2]
# Out:
# '    <tag>\n        <name>$DEVICE_NAME/DAP-SP</name>\n        <group></group>\n        <resourceLocator>\n            <protocolName>BACN</protocolName>\n            <object_type>AV</object_type>\n            <device_id>$DEVICE_ID</device_id>\n            <data_type>float</data_type>\n            <arraysize></arraysize>\n            <conversion></conversion>\n            <object_instance>19</object_instance>\n            <object_property>85</object_property>\n            <array_index>-1</array_index>\n            <write_priority>10</write_priority>\n            <cov>false</cov>\n        </resourceLocator>\n        <encoding></encoding>\n        <refreshTime>1000</refreshTime>\n        <accessMode>READ</accessMode>\n        <active>false</active>\n        <TAGLOCATOR></TAGLOCATOR>\n        <comment></comment>\n        <simulator>\n            <DataSimulator>Variables</DataSimulator>\n            <Amplitude></Amplitude>\n            <Simulator_offset></Simulator_offset>\n            <Period></Period>\n        </simulator>\n        <scaling>\n            <enableScaling>false</enableScaling>\n            <scalingType>byFormula</scalingType>\n            <enableLimits>false</enableLimits>\n            <factors>\n                <s1>1</s1>\n                <s2>1</s2>\n                <s3>0</s3>\n                <tagS1></tagS1>\n                <tagS2></tagS2>\n                <tagS3></tagS3>\n            </factors>\n            <limits>\n                <eumin>0</eumin>\n                <eumax>100</eumax>\n                <elmin></elmin>\n                <elmax></elmax>\n            </limits>\n        </scaling>\n        <decimalDigits>\n            <ddTag></ddTag>\n            <ddDigits></ddDigits>\n        </decimalDigits>\n        <castType></castType>\n        <default></default>\n        <min>-3.40282e+38</min>\n        <max>3.40282e+38</max>\n        <statesText></statesText>\n    </tag>\n'

# %%
_nep = [("TP101", 331908),
        ("TP102", 331909),
        ("TP102_1", 331910),
        ("TP104", 331911),
        ("TP105", 331912),
        ("TP106", 331913),
        ("TP111", 331914),
        ("TP112", 331915),
        ("TP113A", 331916),
        ("TP113B", 331917),
        ]
_neptags = build_from_templates(nep_template[1], _nep)
_uc = [("PCG-9-004", 5904),
        ("PCG-9-005", 5905),
        ("PCG-9-006", 5906)
        ]
_uctags = build_from_templates(uc_template[1], _uc)
write_tags_import_file("CCB",merge_templates([_uctags,_neptags]))
# Out:
#     <tag>
#         <name>$DEVICE_NAME/Intern_Temp</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>AI</object_type>
#             <device_id>$DEVICE_ID</device_id>
#             <data_type>float</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>1</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>0</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment>Intern_Temp</comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>TP101/Intern_Temp</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>AI</object_type>
#             <device_id>$331908</device_id>
#             <data_type>float</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>1</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>0</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment>Intern_Temp</comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>$DEVICE_NAME/Extern_Temp</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>AI</object_type>
#             <device_id>$DEVICE_ID</device_id>
#             <data_type>float</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>2</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>0</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment>Extern_Temp</comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>TP101/Extern_Temp</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>AI</object_type>
#             <device_id>$331908</device_id>
#             <data_type>float</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>2</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>0</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment>Extern_Temp</comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>$DEVICE_NAME/ChangeOverTemp</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>AI</object_type>
#             <device_id>$DEVICE_ID</device_id>
#             <data_type>float</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>3</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>0</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment>ChangeOverTemp</comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>TP101/ChangeOverTemp</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>AI</object_type>
#             <device_id>$331908</device_id>
#             <data_type>float</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>3</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>0</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment>ChangeOverTemp</comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>$DEVICE_NAME/ControlTemp</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>AV</object_type>
#             <device_id>$DEVICE_ID</device_id>
#             <data_type>float</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>1</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>10</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment>ControlTemp</comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>TP101/ControlTemp</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>AV</object_type>
#             <device_id>$331908</device_id>
#             <data_type>float</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>1</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>10</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment>ControlTemp</comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>$DEVICE_NAME/HeatingDemand1</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>AV</object_type>
#             <device_id>$DEVICE_ID</device_id>
#             <data_type>float</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>2</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>10</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment>HeatingDemand1</comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>TP101/HeatingDemand1</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>AV</object_type>
#             <device_id>$331908</device_id>
#             <data_type>float</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>2</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>10</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment>HeatingDemand1</comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>$DEVICE_NAME/CoolingDemand1</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>AV</object_type>
#             <device_id>$DEVICE_ID</device_id>
#             <data_type>float</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>3</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>10</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment>CoolingDemand1</comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>TP101/CoolingDemand1</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>AV</object_type>
#             <device_id>$331908</device_id>
#             <data_type>float</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>3</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>10</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment>CoolingDemand1</comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>$DEVICE_NAME/Intern_Temp_Offset</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>AV</object_type>
#             <device_id>$DEVICE_ID</device_id>
#             <data_type>float</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>5</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>10</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment>Intern_Temp_Offset</comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>TP101/Intern_Temp_Offset</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>AV</object_type>
#             <device_id>$331908</device_id>
#             <data_type>float</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>5</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>10</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment>Intern_Temp_Offset</comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>$DEVICE_NAME/Extern_Temp_Offset</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>AV</object_type>
#             <device_id>$DEVICE_ID</device_id>
#             <data_type>float</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>6</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>10</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment>Extern_Temp_Offset</comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>TP101/Extern_Temp_Offset</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>AV</object_type>
#             <device_id>$331908</device_id>
#             <data_type>float</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>6</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>10</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment>Extern_Temp_Offset</comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>$DEVICE_NAME/Temp_SetPointOcc</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>AV</object_type>
#             <device_id>$DEVICE_ID</device_id>
#             <data_type>float</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>7</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>10</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment>Temp_SetPointOcc</comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>TP101/Temp_SetPointOcc</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>AV</object_type>
#             <device_id>$331908</device_id>
#             <data_type>float</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>7</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>10</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment>Temp_SetPointOcc</comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>$DEVICE_NAME/Min_SetPointOcc</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>AV</object_type>
#             <device_id>$DEVICE_ID</device_id>
#             <data_type>float</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>8</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>10</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment>Min_SetPointOcc</comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>TP101/Min_SetPointOcc</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>AV</object_type>
#             <device_id>$331908</device_id>
#             <data_type>float</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>8</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>10</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment>Min_SetPointOcc</comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>$DEVICE_NAME/Max_SetPointOcc</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>AV</object_type>
#             <device_id>$DEVICE_ID</device_id>
#             <data_type>float</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>9</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>10</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment>Max_SetPointOcc</comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>TP101/Max_SetPointOcc</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>AV</object_type>
#             <device_id>$331908</device_id>
#             <data_type>float</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>9</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>10</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment>Max_SetPointOcc</comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>$DEVICE_NAME/SetPointCoolNoOcc</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>AV</object_type>
#             <device_id>$DEVICE_ID</device_id>
#             <data_type>float</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>10</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>10</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment>SetPointCoolNoOcc</comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>TP101/SetPointCoolNoOcc</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>AV</object_type>
#             <device_id>$331908</device_id>
#             <data_type>float</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>10</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>10</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment>SetPointCoolNoOcc</comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>$DEVICE_NAME/SetPointHeatNoOcc</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>AV</object_type>
#             <device_id>$DEVICE_ID</device_id>
#             <data_type>float</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>11</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>10</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment>SetPointHeatNoOcc</comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>TP101/SetPointHeatNoOcc</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>AV</object_type>
#             <device_id>$331908</device_id>
#             <data_type>float</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>11</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>10</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment>SetPointHeatNoOcc</comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
# ...
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>$DEVICE_NAME/HTG-TYPE</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>MV</object_type>
#             <device_id>$DEVICE_ID</device_id>
#             <data_type>unsignedInt</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>10776</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>10</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment></comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>PCG-9-006/HTG-TYPE</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>MV</object_type>
#             <device_id>$5906</device_id>
#             <data_type>unsignedInt</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>10776</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>10</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment></comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>$DEVICE_NAME/PWREXHAUST-EN</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>MV</object_type>
#             <device_id>$DEVICE_ID</device_id>
#             <data_type>unsignedInt</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>11122</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>10</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment></comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>PCG-9-006/PWREXHAUST-EN</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>MV</object_type>
#             <device_id>$5906</device_id>
#             <data_type>unsignedInt</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>11122</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>10</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment></comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>$DEVICE_NAME/PWREXHAUST-STATE</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>MV</object_type>
#             <device_id>$DEVICE_ID</device_id>
#             <data_type>unsignedInt</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>11131</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>10</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment></comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>PCG-9-006/PWREXHAUST-STATE</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>MV</object_type>
#             <device_id>$5906</device_id>
#             <data_type>unsignedInt</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>11131</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>10</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment></comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>$DEVICE_NAME/ZNT-STATE</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>MV</object_type>
#             <device_id>$DEVICE_ID</device_id>
#             <data_type>unsignedInt</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>12097</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>10</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment></comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>
#
#     <tag>
#         <name>PCG-9-006/ZNT-STATE</name>
#         <group></group>
#         <resourceLocator>
#             <protocolName>BACN</protocolName>
#             <object_type>MV</object_type>
#             <device_id>$5906</device_id>
#             <data_type>unsignedInt</data_type>
#             <arraysize></arraysize>
#             <conversion></conversion>
#             <object_instance>12097</object_instance>
#             <object_property>85</object_property>
#             <array_index>-1</array_index>
#             <write_priority>10</write_priority>
#             <cov>false</cov>
#         </resourceLocator>
#         <encoding></encoding>
#         <refreshTime>1000</refreshTime>
#         <accessMode>READ</accessMode>
#         <active>false</active>
#         <TAGLOCATOR></TAGLOCATOR>
#         <comment></comment>
#         <simulator>
#             <DataSimulator>Variables</DataSimulator>
#             <Amplitude></Amplitude>
#             <Simulator_offset></Simulator_offset>
#             <Period></Period>
#         </simulator>
#         <scaling>
#             <enableScaling>false</enableScaling>
#             <scalingType>byFormula</scalingType>
#             <enableLimits>false</enableLimits>
#             <factors>
#                 <s1>1</s1>
#                 <s2>1</s2>
#                 <s3>0</s3>
#                 <tagS1></tagS1>
#                 <tagS2></tagS2>
#                 <tagS3></tagS3>
#             </factors>
#             <limits>
#                 <eumin>0</eumin>
#                 <eumax>100</eumax>
#                 <elmin></elmin>
#                 <elmax></elmax>
#             </limits>
#         </scaling>
#         <decimalDigits>
#             <ddTag></ddTag>
#             <ddDigits></ddDigits>
#         </decimalDigits>
#         <castType></castType>
#         <default></default>
#         <min>-3.40282e+38</min>
#         <max>3.40282e+38</max>
#         <statesText></statesText>
#     </tag>

# %%
#write_tags_import_file("NEPTRONICS", _tags)
